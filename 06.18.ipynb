# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/weather/weather2.csv")
df.head()
# Out:
#                   time  이화동강수  이화동기온  수영동강수  수영동기온
# 0  2020-01-01 00:00:00    0.1   -3.9    0.0    2.5
# 1  2020-01-01 01:00:00    0.0   -3.1    0.0    3.4
# 2  2020-01-01 02:00:00    0.0   -1.8    0.0    3.8
# 3  2020-01-01 03:00:00    0.0   -0.8    0.0    4.6
# 4  2020-01-01 04:00:00    0.0   -0.1    0.0    5.1

# %%
df['time'] = pd.to_datetime(df['time'])
target = df[(df['time'].dt.month >= 6) & (df['time'].dt.month <= 8)]
result = len(target[target['이화동기온'] > target['수영동기온']])
print(result)
# Out:
# 1415

# %%
df['time'] = pd.to_datetime(df['time'])
result1 = df[df['이화동강수'] == df['이화동강수'].max()].time.values
result2 = df[df['수영동강수'] == df['수영동강수'].max()].time.values
print(result1, result2)
# Out:
# ['2020-09-30T09:00:00.000000000'] ['2020-07-23T12:00:00.000000000']

# %%
import pandas as pd
#데이터 로드
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/churn/train.csv")
df.head()
df.shape
df['Exited'].value_counts()
# Out:
# Exited
# 0    6370
# 1    1629
# Name: count, dtype: int64

# %%
result = df[df['Gender']=='Male'].groupby(['Geography'])['Exited'].sum().sort_values(ascending=False).head(1)
print(result)
# Out:
# Geography
# Germany    287
# Name: Exited, dtype: int64

# %%
target = df[(df['HasCrCard'] == 1) & (df['IsActiveMember'] == 1)]['Age'].mean()
print(round(target,4))
# Out:
# 39.6102

# %%
target = df[df['Balance'] >= df['Balance'].median()]['CreditScore'].std()
print(round(target,3))
# Out:
# 97.295

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/smoke/train.csv")
df.head()
# Out:
#   성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  청력(우)  \
# 0    F           55        145         55  73.0    0.7    0.5    1.0    1.0
# 1    M           40        180         55  74.0    1.5    1.5    1.0    1.0
# 2    F           55        150         50  72.0    1.0    0.2    1.0    1.0
# 3    M           40        170         85  89.0    1.0    0.8    1.0    1.0
# 4    F           40        155         45  62.0    0.5    1.0    1.0    1.0
#
#    수축기혈압  ...   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  흡연상태  \
# 0  129.0  ...  12.9  1.0      0.9       172.0       209.0   15.0     0
# 1  102.0  ...  15.6  1.0      0.8        30.0        19.0   23.0     1
# 2  116.0  ...  14.1  1.0      1.0        31.0        19.0   10.0     0
# 3  124.0  ...  16.7  1.0      1.0        26.0        38.0  108.0     1
# 4  127.0  ...  12.9  1.0      0.7        20.0        11.0   13.0     0
#
#    구강검진수검여부  치아우식증유무  치석
# 0         Y      0.0   Y
# 1         Y      0.0   Y
# ...

# %%
df['혈압차'] = df['수축기혈압'] - df['이완기혈압']
target = df.groupby('연령대코드(5세단위)')['혈압차'].var().sort_values(ascending=False).index[4]
print(target)
# Out:
# 60

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/insurance/train.csv")
print(df.head())
print(df['Vehicle_Age'].value_counts())
# Out:
#        id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  188957  Female   25                1         17.0                   1
# 1  275631    Male   20                1         22.0                   0
# 2  329036  Female   40                1         41.0                   0
# 3  227288  Female   28                1         30.0                   1
# 4  300441  Female   50                1         28.0                   0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    < 1 Year             No         38785.0                 152.0       59
# 1    < 1 Year             No          2630.0                 160.0      113
# 2    1-2 Year            Yes         33165.0                 124.0      188
# 3    < 1 Year             No         29038.0                 152.0      233
# 4    1-2 Year            Yes         31325.0                 124.0      258
#
#    Response
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
target = df[df['Vehicle_Age'] == '> 2 Years']
result = target[(target['Annual_Premium'] >= target['Annual_Premium'].median())]['Vintage'].mean()
print(result)
# Out:
# 154.55906743858552

# %%
answer = df[(df['Vehicle_Age']=='> 2 Years') & (df['Annual_Premium'] >= df['Annual_Premium'].median())]['Vintage'].mean()
print(answer)
# Out:
# 154.43647182359118

# %%
target = df.groupby(['Vehicle_Age','Gender'],as_index=False)['Annual_Premium'].mean()
target.pivot(index='Vehicle_Age', columns='Gender', values='Annual_Premium')
# Out:
# Gender             Female          Male
# Vehicle_Age
# 1-2 Year     30762.245001  30413.088469
# < 1 Year     29972.286702  30310.982212
# > 2 Years    36108.366374  35303.870627

# %%
import pandas as pd
#데이터 로드
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/MedicalCost/x_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/MedicalCost/y_train.csv")
x_test= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/MedicalCost/x_test.csv")

x_df = pd.merge(x_train,y_train, on='ID')

# %%
print(x_df.shape,'\n')
print(x_df.head(3),'\n')
print(x_df.info(),'\n')
print(x_df.describe(),'\n')
print(x_df.isnull().sum())
# Out:
# (1070, 8)
#
#    ID  age     sex     bmi  children smoker     region      charges
# 0   2   35  female  35.860         2     no  southeast   5836.52040
# 1   3   28  female  23.845         2     no  northwest   4719.73655
# 2   4   23  female  32.780         2    yes  southeast  36021.01120
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        1070 non-null   int64
#  1   age       1070 non-null   int64
#  2   sex       1070 non-null   object
#  3   bmi       1070 non-null   float64
#  4   children  1070 non-null   int64
#  5   smoker    1070 non-null   object
#  6   region    1070 non-null   object
#  7   charges   1070 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 67.0+ KB
# None
#
#                 ID          age          bmi     children       charges
# ...

# %%
print(x_test.shape,'\n')
print(x_test.head(3),'\n')
print(x_test.info(),'\n')
print(x_test.describe(),'\n')
print(x_test.isnull().sum())
# Out:
# (268, 7)
#
#    ID  age     sex     bmi  children smoker     region
# 0   0   34    male  42.900         1     no  southwest
# 1   1   18  female  28.215         0     no  northeast
# 2   5   43  female  29.900         1     no  southwest
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        268 non-null    int64
#  1   age       268 non-null    int64
#  2   sex       268 non-null    object
#  3   bmi       268 non-null    float64
#  4   children  268 non-null    int64
#  5   smoker    268 non-null    object
#  6   region    268 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 14.8+ KB
# None
#
#                 ID         age         bmi    children
# count   268.000000  268.000000  268.000000  268.000000
# mean    683.652985   37.832090   30.186138    1.171642
# ...

# %%
x = x_df.drop(['ID','charges'],axis=1)
y= x_df['charges']
target = x_test.drop('ID',axis=1)

# %%
mms_col = x.select_dtypes(exclude='object').columns

from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
x[mms_col] = mms.fit_transform(x[mms_col])
target[mms_col] = mms.transform(target[mms_col])

# %%
obj_col = x.select_dtypes(include='object').columns

for col in obj_col:
  print(col)
  print(x[col].unique(), '\n')
# Out:
# sex
# ['female' 'male']
#
# smoker
# ['no' 'yes']
#
# region
# ['southeast' 'northwest' 'southwest' 'northeast']

# %%
x = pd.get_dummies(x, columns=obj_col, dtype=int)
target = pd.get_dummies(target, columns = obj_col, dtype=int)

# %%
print(x)
print(y)
print(target)
# Out:
#            age       bmi  children  sex_female  sex_male  smoker_no  \
# 0     0.369565  0.535378       0.4           1         0          1
# 1     0.217391  0.212133       0.4           1         0          1
# 2     0.108696  0.452515       0.4           1         0          0
# 3     0.739130  0.251278       0.4           1         0          0
# 4     0.978261  0.641377       0.6           0         1          1
# ...        ...       ...       ...         ...       ...        ...
# 1065  0.086957  0.388485       0.0           1         0          0
# 1066  0.695652  0.426823       0.0           0         1          0
# 1067  0.000000  0.408125       0.0           1         0          1
# 1068  0.826087  0.288808       0.2           0         1          0
# 1069  0.326087  0.331181       0.2           1         0          1
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# 0              0                 0                 0                 1
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x,y,test_size=0.2, random_state=810)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

rf = RandomForestRegressor(random_state=810)
params = {'n_estimators':range(2,10), 'max_depth':range(2,15)}

gscv = GridSearchCV(rf, param_grid=params, cv=5)
gscv.fit(x_train, y_train)
print(gscv.best_params_)
# Out:
# {'max_depth': 5, 'n_estimators': 9}

# %%
model = RandomForestRegressor(max_depth=10, n_estimators=9, random_state=810)
model.fit(x_train, y_train)
pred_v = model.predict(x_val)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
print('mse:', mean_squared_error(y_val, pred_v))
print('rmse:', (mean_squared_error(y_val, pred_v)) ** 0.5)
print('rmse:', mean_squared_error(y_val, pred_v, squared=False))
print('mae:', mean_absolute_error(y_val, pred_v))
print('r2_score:', r2_score(y_val,pred_v))
# Out:
# mse: 28769326.18012992
# rmse: 5363.704520210814
# rmse: 5363.704520210814
# mae: 2896.661672497731
# r2_score: 0.846500027386718

# %%
pred = model.predict(target)

# %%
result = pd.DataFrame({'ID':x_test['ID'],'pred':pred})
result.to_csv('수험번호.csv', index=False)
print(result)
# Out:
#        ID          pred
# 0       0   8229.573378
# 1       1   2209.424993
# 2       5   6905.610286
# 3      21  14868.712007
# 4      26  11363.256992
# ..    ...           ...
# 263  1327  11998.665573
# 264  1328  10973.723535
# 265  1329   2252.942003
# 266  1331  35866.725564
# 267  1334  13093.782240
#
# [268 rows x 2 columns]
