# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/scipy/normal1.csv')
plt.hist(df)
plt.show()
print(df.head())
# Out:
#          data
# 0  295.979767
# 1  289.703739
# 2  300.609670
# 3  299.890856
# 4  293.159612

# %%
from scipy.stats import shapiro

ans = shapiro(df)
print(ans)

if ans.pvalue > 0.05:
  print('유의수준 5%에서 귀무가설을 기각할 수 없음')

else:
  print('유의수준 5%에서 귀무가설을 기각할 수 있음')
# Out:
# ShapiroResult(statistic=0.9981444478034973, pvalue=0.34849318861961365)
# 유의수준 5%에서 귀무가설을 기각할 수 없음

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/scipy/normal3.csv')
plt.hist(df)
plt.show()

print(df.head())
# Out:
#        data
# 0  0.880145
# 1 -0.021619
# 2  0.509888
# 3  0.179442
# 4  0.493778

# %%
from scipy.stats import shapiro

ans = shapiro(df)

if ans.pvalue > 0.05:
  print('유의수준: {0}, 유의수준 5% 수준에서 귀무가설을 기각할수 없음(정규성을 만족함)'. format(ans.pvalue))
else:
  print('유의수준:{0}, 유의수준 5% 수준에서 귀무가설을 기각할 수 있음(정규성을 만족하지 않음)'. format(ans.pvalue))
# Out:
# 유의수준:2.309641794969743e-16, 유의수준 5% 수준에서 귀무가설을 기각할 수 있음(정규성을 만족하지 않음)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/scipy/normal3.csv')
log_y_data = np.log1p(df)

plt.hist(log_y_data)
plt.show()

print(df.head)
# Out:
# <bound method NDFrame.head of          data
# 0    0.880145
# 1   -0.021619
# 2    0.509888
# 3    0.179442
# 4    0.493778
# ..        ...
# 995 -0.229930
# 996  0.087762
# 997  0.651349
# 998  2.489877
# 999  0.704755
#
# [1000 rows x 1 columns]>

# %%
import scipy.stats as stats

ans = stats.shapiro(log_y_data)

if ans.pvalue > 0.05:
  print('유의확률:{0}, 유의수준 5% 수준에서 귀무가설을 기각할수 없음(정규성을 만족)'.format(ans.pvalue))
else:
  print('유의확률:{0}, 유의수준 5%수준에서 귀무가설을 기각할 수 있음(정규성을 만족하지 않음)'.format(ans.pvalue))
# Out:
# 유의확률:0.17540602385997772, 유의수준 5% 수준에서 귀무가설을 기각할수 없음(정규성을 만족)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/scipy/normal6.csv')
plt.hist(df)
plt.show()

print(df.shape)
print(df.head)
# Out:
# (6000, 1)
# <bound method NDFrame.head of             data
# 0     296.016803
# 1     299.628476
# 2     298.232057
# 3     293.256749
# 4     301.037710
# ...          ...
# 5995  304.008424
# 5996  301.043219
# 5997  302.542420
# 5998  294.456145
# 5999  301.733819
#
# [6000 rows x 1 columns]>

# %%
import scipy.stats as stats

ans = stats.anderson(df['data'].values)
print(ans)

a = ans.critical_values[2]
b = ans.statistic

if a > b:
  print('유의확률:{0}, 유의수준 5%에서 귀무가설을 기각할 수 없음(정규성을 만족)'.format(a))
else:
  print('유의확률:{0}, 유의수준 5%에서 귀무가설을 기각할 수 있음(정규성을 만족하지 않음)'.format(a))
# Out:
# AndersonResult(statistic=0.8266993530405671, critical_values=array([0.576, 0.656, 0.786, 0.917, 1.091]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=299.95980319533163, scale=5.031806887885131)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')
# 유의확률:0.786, 유의수준 5%에서 귀무가설을 기각할 수 있음(정규성을 만족하지 않음)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/scipy/height1.csv')
df1= df.copy()

print(df1.head())
print(df1.shape)
# Out:
#        height
# 0  160.237691
# 1  164.747324
# 2  165.401628
# 3  168.801627
# 4  153.199021
# (100, 1)

# %%
from scipy.stats import ttest_1samp
from scipy.stats import willcoxon
from scipy.stats import shapio
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-44-143362f6df22> in <cell line: 2>()
#       1 from scipy.stats import ttest_1samp
# ----> 2 from scipy.stats import willcoxon
#       3 from scipy.stats import shapio
#
# ImportError: cannot import name 'willcoxon' from 'scipy.stats' (/usr/local/lib/python3.10/dist-packages/scipy/stats/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
a: (f'H0: 평균키는 165이다')
b: (f'h1: 평균키는 165가 아니다')

#정규성검정
statics, pvalue = shapiro(df)
print('샤피로 정규성 검정 pvalue:',pvalue,'이므로')

if pvalue < 0.05:
  print('귀무가설 기각, 정규성을 불만족하므로 윌콕스 부호 검정진행 \n')
  print('윌콕스 부호 검정의 귀무가설은 {0}이고 대립가설은{1}이다'.format(a, b))

  statics, pvalue = willcoxon(df['height']-165, alternative='two')

  if pvalue < 0.05:
    print('pvalue 값은 {0}이므로 귀무가설을 기각한다'.format(pvalue))
  else:
    print('pvalue 값은 {0}이므로 귀무가설을 기각하지 않는다'.format(pvalue))

else:
  print('귀무가설 기각, 정규성을 만족하므로 단일표본 검정을 진행한다 \n')
  print('단일표본 검정의 귀무가설은{0}이고 대립가설은{1}이다'.format(a, b))

  statics, pvalue = ttest_1samp(df['height'],165)
  if pvalue < 0.05:
    print('pvalue 값은 {0}이므로 귀무가설을 기각한다'.format(pvalue))
  else:
    print('pvalue 값은 {0}이므로 귀무가설을 기각하지 않는다'.format(pvalue))
# Out:
# 샤피로 정규성 검정 pvalue: 0.4558176100254059 이므로
# 귀무가설 기각, 정규성을 만족하므로 단일표본 검정을 진행한다
#
# 단일표본 검정의 귀무가설은0.786이고 대립가설은0.8266993530405671이다
# pvalue 값은 0.0018367171548080209이므로 귀무가설을 기각한다

# %%
a ='H0: 평균키는 165이다'
b ='h1: 평균키는 165가 아니다'

#정규성검정
statics, pvalue = shapiro(df)
print('샤피로 정규성 검정 pvalue:',pvalue,'이므로')

if pvalue < 0.05:
  print('귀무가설 기각, 정규성을 불만족하므로 윌콕스 부호 검정진행 \n')
  print(f'윌콕스 부호 검정의 귀무가설{a}이고 대립가설{b}이다')

  statics, pvalue = willcoxon(df['height']-165, alternative='two')

  if pvalue < 0.05:
    print(f'pvalue 값은 {pvalue}이므로 귀무가설을 기각한다')
  else:
    print(f'pvalue 값은 {pvalue}이므로 귀무가설을 기각하지 않는다')
else:
  print('귀무가설 기각, 정규성을 만족하므로 단일표본 검정을 진행한다 \n')
  print(f'단일표본 검정의 귀무가설{a}이고 대립가설{b}이다')

  statics, pvalue = ttest_1samp(df['height'],165)
  if pvalue < 0.05:
    print(f'pvalue 값은 {pvalue}이므로 귀무가설을 기각한다')
  else:
    print(f'pvalue 값은 {pvalue}이므로 귀무가설을 기각하지 않는다')
# Out:
# 샤피로 정규성 검정 pvalue: 0.4558176100254059 이므로
# 귀무가설 기각, 정규성을 만족하므로 단일표본 검정을 진행한다
#
# 단일표본 검정의 귀무가설H0: 평균키는 165이다이고 대립가설h1: 평균키는 165가 아니다이다
# pvalue 값은 0.0018367171548080209이므로 귀무가설을 기각한다

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/scipy/scipy2.csv')
df.head()

df1 = df.copy()
print(df1.shape)
print(df1.head(5))
# Out:
# (480, 2)
#   class  score
# 0     A     84
# 1     A     59
# 2     A     49
# 3     A     57
# 4     A     82

# %%
from scipy.stats import levene
from scipy.stats import fligner
from scipy.stats import bartlett

a = df[df['class'] =='A'].score
b = df[df['class'] =='B'].score

print(bartlett(a,b))

print(fligner(a,b,center='median')) #default
print(fligner(a,b,center='mean'))

print(levene(a,b, center='median')) #default
print(levene(a,b,center='mean'))

a = levene(a,b,center='mean')

if a.pvalue > 0.05:
  print(f'pvalue 값은 {a.pvalue}이므로 귀무가설을 기각할수 없다(각 그룹은 등분산이다)')
else:
   print(f'pvalue 값은 {a.pvalue}이므로 귀무가설을 기각한다(각 그룹은 등분산이 아니다)')
# Out:
# BartlettResult(statistic=0.26035880448930865, pvalue=0.609873758447687)
# FlignerResult(statistic=0.7281251154135562, pvalue=0.39349158741002765)
# FlignerResult(statistic=0.8272211734319945, pvalue=0.36307728836821906)
# LeveneResult(statistic=0.3145466542912649, pvalue=0.5751662820554713)
# LeveneResult(statistic=0.5086970687685527, pvalue=0.4760514837800255)
# pvalue 값은 0.4760514837800255이므로 귀무가설을 기각할수 없다(각 그룹은 등분산이다)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df1 = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/scipy/ind1.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/scipy/ind2.csv')


plt.hist(df1,label='df1',alpha=0.4)
plt.hist(df2,label="df2",alpha=0.4)
plt.xlabel('Score bins')
plt.ylabel('Counts')
plt.legend()
plt.show()

# %%
from scipy.stats import shapiro
print(shapiro(df1))
print(shapiro(df2))

# 두 그룹 모두 Shapiro검정 결과 귀무가설(정규성을 가진다)을 기각 하지 못한다. 두 그룹은 정규성을 가진다.

from scipy.stats import levene
print()
print(levene(df1['data'],df2['data']))
# 두그룹은 levene 검정을 확인해 본결과 pvalue 는 0.11로 귀무가실을 기각히지 못한다. 그러므로 등분산은 가진다

from scipy.stats import ttest_ind
print()
print(ttest_ind(df1,df2,equal_var=True))

# 등분산이기 때문에 equal_var=True 파라미터를 주고 ttest_ind 모듈을 이용하여 t test를 진행한다
# pvalue는 0.006이므로 귀무가설(각 그룹의 평균값은 동일하다)를 기각하고 대립가설을 채택한다
# Out:
# ShapiroResult(statistic=0.9860946536064148, pvalue=0.379673033952713)
# ShapiroResult(statistic=0.990182638168335, pvalue=0.6793646216392517)
#
# LeveneResult(statistic=2.5337683795339547, pvalue=0.11302904824469093)
#
# TtestResult(statistic=array([2.76719074]), pvalue=array([0.00619015]), df=array([198.]))
